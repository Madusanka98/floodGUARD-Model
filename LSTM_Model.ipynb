# %%
import pandas as pd

data = pd.read_csv('rainfall-riverheight-history-Rathnapura.csv')

data.head()
# Out:
#         Date      station  river_hight  rainfall
# 0  6/14/2024    Putupaula         0.75       1.4
# 1  6/14/2024     Ellagawa         5.25       0.0
# 2  6/14/2024   Rathnapura         1.38       0.0
# 3  6/14/2024       Magura         1.75       0.0
# 4  6/14/2024  Kalawellawa         2.47       0.0

# %%
rathnapura_data = data[data['station'] == 'Putupaula']

# Convert 'Date' to datetime format
rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])

# Convert 'Date' to datetime format
rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])

# Check the processed data and look for missing values
rathnapura_data.info(), rathnapura_data.head()

# Filter the data for the "Rathnapura" station and sort by date
rathnapura_data = data[data['station'] == 'Putupaula'].sort_values('Date')


#rename river height column as 'river_height'
rathnapura_data.rename(columns={'river_hight': 'river_height'}, inplace=True)


rathnapura_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 436 entries, 0 to 2105
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         436 non-null    datetime64[ns]
#  1   station      436 non-null    object
#  2   river_hight  436 non-null    float64
#  3   rainfall     436 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 17.0+ KB
# C:\Users\Madusanka(MadusankaB\AppData\Local\Temp\ipykernel_7264\1972735815.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])
# C:\Users\Madusanka(MadusankaB\AppData\Local\Temp\ipykernel_7264\1972735815.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])
#            Date    station  river_height  rainfall
# 290    1/1/2024  Putupaula          0.82      14.2
# 1370  1/10/2022  Putupaula          1.11       3.7
# 245   1/10/2024  Putupaula          0.60       0.0
# 240   1/11/2024  Putupaula          0.43       0.3
# 235   1/12/2024  Putupaula          0.46       0.0

# %%
# remove outliers
rathnapura_data = rathnapura_data[rathnapura_data['rainfall'] < 200]

# add rolling mean to missing values
rathnapura_data['rainfall'] = rathnapura_data['rainfall'].fillna(rathnapura_data['rainfall'].rolling(30, min_periods=1).mean())

# #fill missing values with the mean of the monthly rainfall for each month
# rathnapura_data['rainfall'] = rathnapura_data.groupby(rathnapura_data['Date'].dt.month)['rainfall'].transform(lambda x: x.fillna(x.mean()))

# plot the data
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(rathnapura_data['Date'], rathnapura_data['rainfall'], label='Rainfall')
plt.title('Rainfall in Rathnapura')
plt.xlabel('Date')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#remove outliers
rathnapura_data = rathnapura_data[rathnapura_data['river_height'] < 10]

#add rolling mean to missing values
rathnapura_data['river_height'] = rathnapura_data['river_height'].fillna(rathnapura_data['river_height'].rolling(30, min_periods=1).mean())


#plot river height
plt.figure(figsize=(12, 6))
plt.plot(rathnapura_data['Date'], rathnapura_data['river_height'], label='River Height')
plt.title('River Height in Rathnapura')
plt.xlabel('Date')
plt.ylabel('River Height (m)')
plt.legend()
plt.show()

# %%
# Creating lagged features for river height and rainfall
for lag in range(1, 4):
    rathnapura_data[f'river_height_lag_{lag}'] = rathnapura_data['river_height'].shift(lag)
    rathnapura_data[f'rainfall_lag_{lag}'] = rathnapura_data['rainfall'].shift(lag)

# Dropping rows with missing values that result from lagging
rathnapura_data.dropna(inplace=True)

# Splitting the data into train and test sets
# Let's use the last 20% of the data as test set
split_index = int(len(rathnapura_data) * 0.8)
train_data = rathnapura_data.iloc[:split_index]
test_data = rathnapura_data.iloc[split_index:]

# Show the structure of the dataset with new features and the split
train_data.info(), test_data.info(), train_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 345 entries, 240 to 1600
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                345 non-null    object
#  1   station             345 non-null    object
#  2   river_height        345 non-null    float64
#  3   rainfall            345 non-null    float64
#  4   river_height_lag_1  345 non-null    float64
#  5   rainfall_lag_1      345 non-null    float64
#  6   river_height_lag_2  345 non-null    float64
#  7   rainfall_lag_2      345 non-null    float64
#  8   river_height_lag_3  345 non-null    float64
#  9   rainfall_lag_3      345 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 29.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 735 to 675
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                87 non-null     object
#  1   station             87 non-null     object
#  2   river_height        87 non-null     float64
#  3   rainfall            87 non-null     float64
#  4   river_height_lag_1  87 non-null     float64
#  5   rainfall_lag_1      87 non-null     float64
#  6   river_height_lag_2  87 non-null     float64
#  7   rainfall_lag_2      87 non-null     float64
#  8   river_height_lag_3  87 non-null     float64
#  9   rainfall_lag_3      87 non-null     float64
# dtypes: float64(8), object(2)
# memory usage: 7.5+ KB
# (None,
#  None,
#             Date    station  river_height  rainfall  river_height_lag_1  \
#  240   1/11/2024  Putupaula          0.43       0.3                0.60
#  235   1/12/2024  Putupaula          0.46       0.0                0.43
#  1365  1/13/2022  Putupaula          0.58       3.7                0.46
#  230   1/13/2024  Putupaula          0.37       0.0                0.58
#  225   1/14/2024  Putupaula          0.41       0.0                0.37
#
#        rainfall_lag_1  river_height_lag_2  rainfall_lag_2  river_height_lag_3  \
#  240              0.0                1.11             3.7                0.82
#  235              0.3                0.60             0.0                1.11
#  1365             0.0                0.43             0.3                0.60
#  230              3.7                0.46             0.0                0.43
#  225              0.0                0.58             3.7                0.46
#
#        rainfall_lag_3
#  240             14.2
#  235              3.7
#  1365             0.0
#  230              0.3
#  225              0.0  )

# %%
from sklearn.preprocessing import StandardScaler

# Features and target variable
features = ['river_height_lag_1', 'rainfall_lag_1', 'river_height_lag_2', 'rainfall_lag_2', 'river_height_lag_3', 'rainfall_lag_3']
target = 'river_height'

# Standardizing the features
scaler = StandardScaler()
train_features = scaler.fit_transform(train_data[features])
test_features = scaler.transform(test_data[features])

train_labels = train_data[target]
test_labels = test_data[target]

# Check the first few rows to see the scaling
train_features[:5], train_labels.head()
# Out:
# (array([[-1.04843154, -0.64174101, -0.58427765, -0.49153857, -0.84230168,
#          -0.06675701],
#         [-1.20182418, -0.62960038, -1.04482623, -0.64124842, -0.58067589,
#          -0.49161166],
#         [-1.17475489, -0.64174101, -1.19834242, -0.62910979, -1.04077641,
#          -0.64132235],
#         [-1.06647773, -0.49200653, -1.17125133, -0.64124842, -1.19414326,
#          -0.62918365],
#         [-1.25596276, -0.64174101, -1.06288696, -0.49153857, -1.16707852,
#          -0.64132235]]),
#  240     0.43
#  235     0.46
#  1365    0.58
#  230     0.37
#  225     0.41
#  Name: river_height, dtype: float64)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Assuming 'train_features' and 'train_labels' are your training datasets
# Reshape features for LSTM input (samples, time steps, features)
train_features_reshaped = train_features.reshape((train_features.shape[0], 1, train_features.shape[1]))

# Model definition
model = Sequential([
    # Bidirectional LSTM layer
    Bidirectional(LSTM(200, return_sequences=True, input_shape=(train_features_reshaped.shape[1], train_features_reshaped.shape[2]))),
    Dropout(0.2),  # Dropout for regularization
    LSTM(100),      # Second LSTM layer
    Dropout(0.2),  # Another Dropout layer
    Dense(10, activation='relu', kernel_regularizer=l2(0.01)),  # Dense layer with L2 regularization
    Dense(1, activation='linear')  # Output layer for regression
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mean_squared_error', metrics=['mean_absolute_error'])



# Model training
history = model.fit(
    train_features_reshaped,
    train_labels,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    # callbacks=[early_stopping, model_checkpoint],
    verbose=2
)


# Model evaluation (assuming 'test_features' and 'test_labels' are your test datasets)
test_features_reshaped = test_features.reshape((test_features.shape[0], 1, test_features.shape[1]))
test_loss, test_mae = model.evaluate(test_features_reshaped, test_labels, verbose=2)

print(f'Test Loss: {test_loss}, Test MAE: {test_mae}')

# Optionally plot the history for loss and validation loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# c:\Users\Madusanka(MadusankaB\Documents\Anaconda\AI Model\myenv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 - 8s - 455ms/step - loss: 3.9925 - mean_absolute_error: 1.6683 - val_loss: 6.5817 - val_mean_absolute_error: 2.1459
# Epoch 2/100
# 18/18 - 0s - 28ms/step - loss: 3.9425 - mean_absolute_error: 1.6563 - val_loss: 6.5096 - val_mean_absolute_error: 2.1323
# Epoch 3/100
# 18/18 - 0s - 19ms/step - loss: 3.8910 - mean_absolute_error: 1.6446 - val_loss: 6.4276 - val_mean_absolute_error: 2.1169
# Epoch 4/100
# 18/18 - 0s - 14ms/step - loss: 3.8349 - mean_absolute_error: 1.6315 - val_loss: 6.3358 - val_mean_absolute_error: 2.0997
# Epoch 5/100
# 18/18 - 0s - 21ms/step - loss: 3.7707 - mean_absolute_error: 1.6170 - val_loss: 6.2258 - val_mean_absolute_error: 2.0793
# Epoch 6/100
# 18/18 - 0s - 14ms/step - loss: 3.7085 - mean_absolute_error: 1.6024 - val_loss: 6.0998 - val_mean_absolute_error: 2.0557
# Epoch 7/100
# 18/18 - 0s - 18ms/step - loss: 3.6267 - mean_absolute_error: 1.5840 - val_loss: 5.9662 - val_mean_absolute_error: 2.0301
# Epoch 8/100
# 18/18 - 0s - 20ms/step - loss: 3.5430 - mean_absolute_error: 1.5639 - val_loss: 5.7960 - val_mean_absolute_error: 1.9973
# Epoch 9/100
# 18/18 - 0s - 17ms/step - loss: 3.4366 - mean_absolute_error: 1.5378 - val_loss: 5.6075 - val_mean_absolute_error: 1.9596
# Epoch 10/100
# 18/18 - 0s - 19ms/step - loss: 3.3133 - mean_absolute_error: 1.5076 - val_loss: 5.3663 - val_mean_absolute_error: 1.9102
# Epoch 11/100
# 18/18 - 0s - 15ms/step - loss: 3.1657 - mean_absolute_error: 1.4727 - val_loss: 5.0841 - val_mean_absolute_error: 1.8494
# Epoch 12/100
# 18/18 - 0s - 18ms/step - loss: 2.9976 - mean_absolute_error: 1.4267 - val_loss: 4.7748 - val_mean_absolute_error: 1.7798
# Epoch 13/100
# 18/18 - 0s - 14ms/step - loss: 2.7969 - mean_absolute_error: 1.3737 - val_loss: 4.4291 - val_mean_absolute_error: 1.7025
# Epoch 14/100
# 18/18 - 0s - 15ms/step - loss: 2.5956 - mean_absolute_error: 1.3146 - val_loss: 4.0630 - val_mean_absolute_error: 1.6165
# Epoch 15/100
# 18/18 - 1s - 31ms/step - loss: 2.4069 - mean_absolute_error: 1.2603 - val_loss: 3.7170 - val_mean_absolute_error: 1.5384
# Epoch 16/100
# 18/18 - 1s - 48ms/step - loss: 2.2211 - mean_absolute_error: 1.2067 - val_loss: 3.4193 - val_mean_absolute_error: 1.4765
# Epoch 17/100
# 18/18 - 1s - 31ms/step - loss: 2.0816 - mean_absolute_error: 1.1581 - val_loss: 3.1621 - val_mean_absolute_error: 1.4272
# Epoch 18/100
# 18/18 - 0s - 14ms/step - loss: 1.9735 - mean_absolute_error: 1.1200 - val_loss: 2.9762 - val_mean_absolute_error: 1.3892
# Epoch 19/100
# 18/18 - 0s - 13ms/step - loss: 1.8597 - mean_absolute_error: 1.0782 - val_loss: 2.8356 - val_mean_absolute_error: 1.3582
# Epoch 20/100
# 18/18 - 0s - 20ms/step - loss: 1.8252 - mean_absolute_error: 1.0600 - val_loss: 2.7432 - val_mean_absolute_error: 1.3342
# Epoch 21/100
# 18/18 - 0s - 13ms/step - loss: 1.7817 - mean_absolute_error: 1.0410 - val_loss: 2.6677 - val_mean_absolute_error: 1.3099
# Epoch 22/100
# 18/18 - 0s - 14ms/step - loss: 1.7114 - mean_absolute_error: 1.0193 - val_loss: 2.6092 - val_mean_absolute_error: 1.2901
# Epoch 23/100
# 18/18 - 0s - 14ms/step - loss: 1.6488 - mean_absolute_error: 0.9920 - val_loss: 2.5433 - val_mean_absolute_error: 1.2661
# Epoch 24/100
# 18/18 - 0s - 13ms/step - loss: 1.6058 - mean_absolute_error: 0.9799 - val_loss: 2.4707 - val_mean_absolute_error: 1.2367
# Epoch 25/100
# 18/18 - 0s - 13ms/step - loss: 1.5917 - mean_absolute_error: 0.9776 - val_loss: 2.4005 - val_mean_absolute_error: 1.2081
# Epoch 26/100
# 18/18 - 0s - 13ms/step - loss: 1.4963 - mean_absolute_error: 0.9445 - val_loss: 2.3350 - val_mean_absolute_error: 1.1857
# Epoch 27/100
# 18/18 - 0s - 13ms/step - loss: 1.4593 - mean_absolute_error: 0.9314 - val_loss: 2.2650 - val_mean_absolute_error: 1.1623
# Epoch 28/100
# 18/18 - 0s - 13ms/step - loss: 1.4157 - mean_absolute_error: 0.9178 - val_loss: 2.1945 - val_mean_absolute_error: 1.1401
# Epoch 29/100
# 18/18 - 0s - 13ms/step - loss: 1.3722 - mean_absolute_error: 0.8929 - val_loss: 2.1185 - val_mean_absolute_error: 1.1140
# Epoch 30/100
# 18/18 - 0s - 13ms/step - loss: 1.3070 - mean_absolute_error: 0.8690 - val_loss: 2.0474 - val_mean_absolute_error: 1.0904
# Epoch 31/100
# 18/18 - 0s - 13ms/step - loss: 1.2193 - mean_absolute_error: 0.8283 - val_loss: 1.9695 - val_mean_absolute_error: 1.0636
# Epoch 32/100
# 18/18 - 0s - 13ms/step - loss: 1.1571 - mean_absolute_error: 0.7959 - val_loss: 1.8872 - val_mean_absolute_error: 1.0342
# Epoch 33/100
# 18/18 - 0s - 13ms/step - loss: 1.0547 - mean_absolute_error: 0.7484 - val_loss: 1.8011 - val_mean_absolute_error: 1.0080
# Epoch 34/100
# 18/18 - 0s - 13ms/step - loss: 1.0179 - mean_absolute_error: 0.7391 - val_loss: 1.7266 - val_mean_absolute_error: 0.9809
# Epoch 35/100
# 18/18 - 0s - 13ms/step - loss: 0.9784 - mean_absolute_error: 0.7039 - val_loss: 1.6620 - val_mean_absolute_error: 0.9606
# Epoch 36/100
# 18/18 - 0s - 12ms/step - loss: 0.9215 - mean_absolute_error: 0.6783 - val_loss: 1.6063 - val_mean_absolute_error: 0.9472
# Epoch 37/100
# 18/18 - 0s - 13ms/step - loss: 0.8774 - mean_absolute_error: 0.6520 - val_loss: 1.5636 - val_mean_absolute_error: 0.9391
# Epoch 38/100
# 18/18 - 0s - 13ms/step - loss: 0.8735 - mean_absolute_error: 0.6579 - val_loss: 1.5247 - val_mean_absolute_error: 0.9315
# Epoch 39/100
# 18/18 - 0s - 13ms/step - loss: 0.8407 - mean_absolute_error: 0.6452 - val_loss: 1.5039 - val_mean_absolute_error: 0.9292
# Epoch 40/100
# 18/18 - 0s - 18ms/step - loss: 0.8228 - mean_absolute_error: 0.6353 - val_loss: 1.4835 - val_mean_absolute_error: 0.9256
# Epoch 41/100
# 18/18 - 0s - 13ms/step - loss: 0.8397 - mean_absolute_error: 0.6509 - val_loss: 1.4714 - val_mean_absolute_error: 0.9236
# Epoch 42/100
# 18/18 - 0s - 13ms/step - loss: 0.8279 - mean_absolute_error: 0.6483 - val_loss: 1.4601 - val_mean_absolute_error: 0.9216
# Epoch 43/100
# 18/18 - 0s - 13ms/step - loss: 0.8036 - mean_absolute_error: 0.6421 - val_loss: 1.4614 - val_mean_absolute_error: 0.9227
# Epoch 44/100
# 18/18 - 0s - 13ms/step - loss: 0.7945 - mean_absolute_error: 0.6338 - val_loss: 1.4497 - val_mean_absolute_error: 0.9194
# Epoch 45/100
# 18/18 - 0s - 13ms/step - loss: 0.8113 - mean_absolute_error: 0.6406 - val_loss: 1.4420 - val_mean_absolute_error: 0.9176
# Epoch 46/100
# 18/18 - 0s - 14ms/step - loss: 0.8321 - mean_absolute_error: 0.6574 - val_loss: 1.4474 - val_mean_absolute_error: 0.9200
# Epoch 47/100
# 18/18 - 0s - 13ms/step - loss: 0.8027 - mean_absolute_error: 0.6480 - val_loss: 1.4464 - val_mean_absolute_error: 0.9208
# Epoch 48/100
# 18/18 - 0s - 13ms/step - loss: 0.7787 - mean_absolute_error: 0.6313 - val_loss: 1.4474 - val_mean_absolute_error: 0.9213
# Epoch 49/100
# 18/18 - 0s - 19ms/step - loss: 0.7777 - mean_absolute_error: 0.6339 - val_loss: 1.4408 - val_mean_absolute_error: 0.9197
# Epoch 50/100
# 18/18 - 0s - 13ms/step - loss: 0.7827 - mean_absolute_error: 0.6392 - val_loss: 1.4354 - val_mean_absolute_error: 0.9182
# Epoch 51/100
# 18/18 - 0s - 13ms/step - loss: 0.7923 - mean_absolute_error: 0.6415 - val_loss: 1.4338 - val_mean_absolute_error: 0.9186
# Epoch 52/100
# 18/18 - 0s - 12ms/step - loss: 0.8129 - mean_absolute_error: 0.6424 - val_loss: 1.4292 - val_mean_absolute_error: 0.9177
# Epoch 53/100
# 18/18 - 0s - 13ms/step - loss: 0.7888 - mean_absolute_error: 0.6364 - val_loss: 1.4269 - val_mean_absolute_error: 0.9173
# Epoch 54/100
# 18/18 - 0s - 13ms/step - loss: 0.8045 - mean_absolute_error: 0.6483 - val_loss: 1.4225 - val_mean_absolute_error: 0.9165
# Epoch 55/100
# 18/18 - 0s - 14ms/step - loss: 0.7958 - mean_absolute_error: 0.6460 - val_loss: 1.4235 - val_mean_absolute_error: 0.9175
# Epoch 56/100
# 18/18 - 0s - 13ms/step - loss: 0.7836 - mean_absolute_error: 0.6315 - val_loss: 1.4233 - val_mean_absolute_error: 0.9174
# Epoch 57/100
# 18/18 - 0s - 18ms/step - loss: 0.7941 - mean_absolute_error: 0.6414 - val_loss: 1.4183 - val_mean_absolute_error: 0.9163
# Epoch 58/100
# 18/18 - 0s - 14ms/step - loss: 0.7830 - mean_absolute_error: 0.6319 - val_loss: 1.4174 - val_mean_absolute_error: 0.9161
# Epoch 59/100
# 18/18 - 0s - 13ms/step - loss: 0.7831 - mean_absolute_error: 0.6281 - val_loss: 1.4129 - val_mean_absolute_error: 0.9149
# Epoch 60/100
# 18/18 - 0s - 13ms/step - loss: 0.7799 - mean_absolute_error: 0.6305 - val_loss: 1.4137 - val_mean_absolute_error: 0.9154
# Epoch 61/100
# 18/18 - 0s - 12ms/step - loss: 0.8194 - mean_absolute_error: 0.6438 - val_loss: 1.4086 - val_mean_absolute_error: 0.9141
# Epoch 62/100
# 18/18 - 0s - 13ms/step - loss: 0.7501 - mean_absolute_error: 0.6222 - val_loss: 1.4110 - val_mean_absolute_error: 0.9147
# Epoch 63/100
# 18/18 - 0s - 13ms/step - loss: 0.7887 - mean_absolute_error: 0.6421 - val_loss: 1.4099 - val_mean_absolute_error: 0.9143
# Epoch 64/100
# 18/18 - 0s - 13ms/step - loss: 0.7491 - mean_absolute_error: 0.6239 - val_loss: 1.4108 - val_mean_absolute_error: 0.9153
# Epoch 65/100
# 18/18 - 0s - 13ms/step - loss: 0.7640 - mean_absolute_error: 0.6263 - val_loss: 1.4095 - val_mean_absolute_error: 0.9146
# Epoch 66/100
# 18/18 - 0s - 13ms/step - loss: 0.7741 - mean_absolute_error: 0.6326 - val_loss: 1.4049 - val_mean_absolute_error: 0.9135
# Epoch 67/100
# 18/18 - 0s - 13ms/step - loss: 0.7530 - mean_absolute_error: 0.6238 - val_loss: 1.4036 - val_mean_absolute_error: 0.9128
# Epoch 68/100
# 18/18 - 0s - 13ms/step - loss: 0.7497 - mean_absolute_error: 0.6203 - val_loss: 1.4018 - val_mean_absolute_error: 0.9125
# Epoch 69/100
# 18/18 - 0s - 14ms/step - loss: 0.7574 - mean_absolute_error: 0.6212 - val_loss: 1.3968 - val_mean_absolute_error: 0.9115
# Epoch 70/100
# 18/18 - 0s - 14ms/step - loss: 0.7898 - mean_absolute_error: 0.6412 - val_loss: 1.3968 - val_mean_absolute_error: 0.9111
# Epoch 71/100
# 18/18 - 0s - 13ms/step - loss: 0.7496 - mean_absolute_error: 0.6203 - val_loss: 1.3925 - val_mean_absolute_error: 0.9096
# Epoch 72/100
# 18/18 - 0s - 13ms/step - loss: 0.7555 - mean_absolute_error: 0.6246 - val_loss: 1.3989 - val_mean_absolute_error: 0.9114
# Epoch 73/100
# 18/18 - 0s - 18ms/step - loss: 0.7520 - mean_absolute_error: 0.6183 - val_loss: 1.3960 - val_mean_absolute_error: 0.9112
# Epoch 74/100
# 18/18 - 0s - 14ms/step - loss: 0.7522 - mean_absolute_error: 0.6222 - val_loss: 1.3915 - val_mean_absolute_error: 0.9099
# Epoch 75/100
# 18/18 - 0s - 14ms/step - loss: 0.7555 - mean_absolute_error: 0.6353 - val_loss: 1.4012 - val_mean_absolute_error: 0.9114
# Epoch 76/100
# 18/18 - 0s - 18ms/step - loss: 0.7466 - mean_absolute_error: 0.6243 - val_loss: 1.4049 - val_mean_absolute_error: 0.9124
# Epoch 77/100
# 18/18 - 0s - 14ms/step - loss: 0.7645 - mean_absolute_error: 0.6312 - val_loss: 1.3997 - val_mean_absolute_error: 0.9111
# Epoch 78/100
# 18/18 - 0s - 14ms/step - loss: 0.7739 - mean_absolute_error: 0.6311 - val_loss: 1.4066 - val_mean_absolute_error: 0.9121
# Epoch 79/100
# 18/18 - 0s - 13ms/step - loss: 0.7334 - mean_absolute_error: 0.6283 - val_loss: 1.3983 - val_mean_absolute_error: 0.9105
# Epoch 80/100
# 18/18 - 0s - 13ms/step - loss: 0.7711 - mean_absolute_error: 0.6378 - val_loss: 1.4029 - val_mean_absolute_error: 0.9118
# Epoch 81/100
# 18/18 - 0s - 13ms/step - loss: 0.7476 - mean_absolute_error: 0.6193 - val_loss: 1.3986 - val_mean_absolute_error: 0.9112
# Epoch 82/100
# 18/18 - 0s - 13ms/step - loss: 0.7467 - mean_absolute_error: 0.6203 - val_loss: 1.3862 - val_mean_absolute_error: 0.9088
# Epoch 83/100
# 18/18 - 0s - 13ms/step - loss: 0.7429 - mean_absolute_error: 0.6322 - val_loss: 1.3764 - val_mean_absolute_error: 0.9058
# Epoch 84/100
# 18/18 - 0s - 12ms/step - loss: 0.7523 - mean_absolute_error: 0.6264 - val_loss: 1.3764 - val_mean_absolute_error: 0.9056
# Epoch 85/100
# 18/18 - 0s - 13ms/step - loss: 0.7491 - mean_absolute_error: 0.6305 - val_loss: 1.3733 - val_mean_absolute_error: 0.9049
# Epoch 86/100
# 18/18 - 0s - 14ms/step - loss: 0.7532 - mean_absolute_error: 0.6377 - val_loss: 1.3813 - val_mean_absolute_error: 0.9066
# Epoch 87/100
# 18/18 - 0s - 14ms/step - loss: 0.7678 - mean_absolute_error: 0.6340 - val_loss: 1.3802 - val_mean_absolute_error: 0.9065
# Epoch 88/100
# 18/18 - 0s - 19ms/step - loss: 0.7534 - mean_absolute_error: 0.6311 - val_loss: 1.3861 - val_mean_absolute_error: 0.9075
# Epoch 89/100
# 18/18 - 0s - 13ms/step - loss: 0.7406 - mean_absolute_error: 0.6228 - val_loss: 1.3853 - val_mean_absolute_error: 0.9078
# Epoch 90/100
# 18/18 - 0s - 18ms/step - loss: 0.7333 - mean_absolute_error: 0.6167 - val_loss: 1.3837 - val_mean_absolute_error: 0.9075
# Epoch 91/100
# 18/18 - 0s - 13ms/step - loss: 0.7432 - mean_absolute_error: 0.6207 - val_loss: 1.3804 - val_mean_absolute_error: 0.9065
# Epoch 92/100
# 18/18 - 0s - 13ms/step - loss: 0.7512 - mean_absolute_error: 0.6305 - val_loss: 1.3774 - val_mean_absolute_error: 0.9059
# Epoch 93/100
# 18/18 - 0s - 13ms/step - loss: 0.7563 - mean_absolute_error: 0.6258 - val_loss: 1.3797 - val_mean_absolute_error: 0.9065
# Epoch 94/100
# 18/18 - 0s - 13ms/step - loss: 0.7456 - mean_absolute_error: 0.6254 - val_loss: 1.3802 - val_mean_absolute_error: 0.9071
# Epoch 95/100
# 18/18 - 0s - 13ms/step - loss: 0.7598 - mean_absolute_error: 0.6322 - val_loss: 1.3779 - val_mean_absolute_error: 0.9063
# Epoch 96/100
# 18/18 - 0s - 13ms/step - loss: 0.7200 - mean_absolute_error: 0.6127 - val_loss: 1.3806 - val_mean_absolute_error: 0.9065
# Epoch 97/100
# 18/18 - 0s - 17ms/step - loss: 0.7409 - mean_absolute_error: 0.6235 - val_loss: 1.3827 - val_mean_absolute_error: 0.9079
# Epoch 98/100
# 18/18 - 0s - 14ms/step - loss: 0.7428 - mean_absolute_error: 0.6262 - val_loss: 1.3763 - val_mean_absolute_error: 0.9055
# Epoch 99/100
# 18/18 - 0s - 13ms/step - loss: 0.7174 - mean_absolute_error: 0.6186 - val_loss: 1.3650 - val_mean_absolute_error: 0.9033
# Epoch 100/100
# 18/18 - 0s - 13ms/step - loss: 0.7304 - mean_absolute_error: 0.6217 - val_loss: 1.3692 - val_mean_absolute_error: 0.9043
# 3/3 - 0s - 12ms/step - loss: 0.9762 - mean_absolute_error: 0.7869
# Test Loss: 0.9761988520622253, Test MAE: 0.7868751287460327

# %%
# save the model
model.save('river_height_prediction_model.keras')

# %%
#load the model
from tensorflow.keras.models import load_model

model = load_model('river_height_prediction_model.keras')

# Predictions
predictions = model.predict(test_features_reshaped)

# Plotting the predictions
plt.figure(figsize=(12, 6))
plt.plot(test_data['Date'], test_data['river_height'], label='Actual')
plt.plot(test_data['Date'], predictions, label='Predicted')
plt.title('River Height Prediction')
plt.xlabel('Date')
plt.ylabel('River Height (m)')
plt.legend()
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step

# %%
import requests

# URL of the FastAPI endpoint
url = 'http://127.0.0.1:8000/forecast/putupaula/'

# Data to be sent to the API
data = {
    "current_height": 2.5,
    "current_rainfall": 10.0
}

# Make the POST request and store the response
response = requests.post(url, json=data)

# Print the status code and the response data
print(f"Status Code: {response.status_code}")
print("Response Data:", response.json())
# Out:
# Status Code: 200
# Response Data: {'predictions': [3.7143733501434326, 3.9162044525146484, 3.949538230895996, 3.9550371170043945, 3.9559433460235596]}
