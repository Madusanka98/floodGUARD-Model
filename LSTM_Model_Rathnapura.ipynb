# %%
import pandas as pd

data = pd.read_csv('rainfall-riverheight-history-Rathnapura.csv')

data.head()
# Out:
#         Date      station  river_hight  rainfall
# 0  6/14/2024    Putupaula         0.75       1.4
# 1  6/14/2024     Ellagawa         5.25       0.0
# 2  6/14/2024   Rathnapura         1.38       0.0
# 3  6/14/2024       Magura         1.75       0.0
# 4  6/14/2024  Kalawellawa         2.47       0.0

# %%
rathnapura_data = data[data['station'] == 'Rathnapura']

# Convert 'Date' to datetime format
rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])

# Convert 'Date' to datetime format
rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])

# Check the processed data and look for missing values
rathnapura_data.info(), rathnapura_data.head()

# Filter the data for the "Rathnapura" station and sort by date
rathnapura_data = data[data['station'] == 'Rathnapura'].sort_values('Date')


#rename river height column as 'river_height'
rathnapura_data.rename(columns={'river_hight': 'river_height'}, inplace=True)


rathnapura_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 436 entries, 2 to 2102
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         436 non-null    datetime64[ns]
#  1   station      436 non-null    object
#  2   river_hight  436 non-null    float64
#  3   rainfall     436 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 17.0+ KB
# C:\Users\Madusanka(MadusankaB\AppData\Local\Temp\ipykernel_22248\1992192254.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])
# C:\Users\Madusanka(MadusankaB\AppData\Local\Temp\ipykernel_22248\1992192254.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])
#            Date     station  river_height  rainfall
# 292    1/1/2024  Rathnapura          1.68       8.5
# 1372  1/10/2022  Rathnapura          1.76       1.8
# 247   1/10/2024  Rathnapura          1.77       0.6
# 242   1/11/2024  Rathnapura          1.64       4.4
# 237   1/12/2024  Rathnapura          1.34       0.0

# %%
# remove outliers
rathnapura_data = rathnapura_data[rathnapura_data['rainfall'] < 200]

# add rolling mean to missing values
rathnapura_data['rainfall'] = rathnapura_data['rainfall'].fillna(rathnapura_data['rainfall'].rolling(30, min_periods=1).mean())

# #fill missing values with the mean of the monthly rainfall for each month
# rathnapura_data['rainfall'] = rathnapura_data.groupby(rathnapura_data['Date'].dt.month)['rainfall'].transform(lambda x: x.fillna(x.mean()))

# plot the data
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(rathnapura_data['Date'], rathnapura_data['rainfall'], label='Rainfall')
plt.title('Rainfall in Rathnapura')
plt.xlabel('Date')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.show()

# %%
#remove outliers
rathnapura_data = rathnapura_data[rathnapura_data['river_height'] < 10]

#add rolling mean to missing values
rathnapura_data['river_height'] = rathnapura_data['river_height'].fillna(rathnapura_data['river_height'].rolling(30, min_periods=1).mean())


#plot river height
plt.figure(figsize=(12, 6))
plt.plot(rathnapura_data['Date'], rathnapura_data['river_height'], label='River Height')
plt.title('River Height in Rathnapura')
plt.xlabel('Date')
plt.ylabel('River Height (m)')
plt.legend()
plt.show()

# %%
# Creating lagged features for river height and rainfall
for lag in range(1, 4):
    rathnapura_data[f'river_height_lag_{lag}'] = rathnapura_data['river_height'].shift(lag)
    rathnapura_data[f'rainfall_lag_{lag}'] = rathnapura_data['rainfall'].shift(lag)

# Dropping rows with missing values that result from lagging
rathnapura_data.dropna(inplace=True)

# Splitting the data into train and test sets
# Let's use the last 20% of the data as test set
split_index = int(len(rathnapura_data) * 0.8)
train_data = rathnapura_data.iloc[:split_index]
test_data = rathnapura_data.iloc[split_index:]

# Show the structure of the dataset with new features and the split
train_data.info(), test_data.info(), train_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 344 entries, 242 to 1602
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                344 non-null    object
#  1   station             344 non-null    object
#  2   river_height        344 non-null    float64
#  3   rainfall            344 non-null    float64
#  4   river_height_lag_1  344 non-null    float64
#  5   rainfall_lag_1      344 non-null    float64
#  6   river_height_lag_2  344 non-null    float64
#  7   rainfall_lag_2      344 non-null    float64
#  8   river_height_lag_3  344 non-null    float64
#  9   rainfall_lag_3      344 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 29.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 737 to 677
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                87 non-null     object
#  1   station             87 non-null     object
#  2   river_height        87 non-null     float64
#  3   rainfall            87 non-null     float64
#  4   river_height_lag_1  87 non-null     float64
#  5   rainfall_lag_1      87 non-null     float64
#  6   river_height_lag_2  87 non-null     float64
#  7   rainfall_lag_2      87 non-null     float64
#  8   river_height_lag_3  87 non-null     float64
#  9   rainfall_lag_3      87 non-null     float64
# dtypes: float64(8), object(2)
# memory usage: 7.5+ KB
# (None,
#  None,
#             Date     station  river_height  rainfall  river_height_lag_1  \
#  242   1/11/2024  Rathnapura          1.64       4.4                1.77
#  237   1/12/2024  Rathnapura          1.34       0.0                1.64
#  1367  1/13/2022  Rathnapura          0.82      12.3                1.34
#  232   1/13/2024  Rathnapura          1.14       0.0                0.82
#  227   1/14/2024  Rathnapura          1.03       0.0                1.14
#
#        rainfall_lag_1  river_height_lag_2  rainfall_lag_2  river_height_lag_3  \
#  242              0.6                1.76             1.8                1.68
#  237              4.4                1.77             0.6                1.76
#  1367             0.0                1.64             4.4                1.77
#  232             12.3                1.34             0.0                1.64
#  227              0.0                0.82            12.3                1.34
#
#        rainfall_lag_3
#  242              8.5
#  237              1.8
#  1367             0.6
#  232              4.4
#  227              0.0  )

# %%
from sklearn.preprocessing import StandardScaler

# Features and target variable
features = ['river_height_lag_1', 'rainfall_lag_1', 'river_height_lag_2', 'rainfall_lag_2', 'river_height_lag_3', 'rainfall_lag_3']
target = 'river_height'

# Standardizing the features
scaler = StandardScaler()
train_features = scaler.fit_transform(train_data[features])
test_features = scaler.transform(test_data[features])

train_labels = train_data[target]
test_labels = test_data[target]

# Check the first few rows to see the scaling
train_features[:5], train_labels.head()
# Out:
# (array([[-0.69804351, -0.72945604, -0.69938876, -0.68491536, -0.74331937,
#          -0.43543506],
#         [-0.7699014 , -0.58953338, -0.69383049, -0.72909448, -0.69817527,
#          -0.68789801],
#         [-0.93572731, -0.75154909, -0.76608801, -0.58919396, -0.69253225,
#          -0.73311525],
#         [-1.22315887, -0.29864154, -0.93283612, -0.75118403, -0.76589143,
#          -0.58992731],
#         [-1.04627791, -0.75154909, -1.22186618, -0.29834814, -0.93518183,
#          -0.75572388]]),
#  242     1.64
#  237     1.34
#  1367    0.82
#  232     1.14
#  227     1.03
#  Name: river_height, dtype: float64)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Assuming 'train_features' and 'train_labels' are your training datasets
# Reshape features for LSTM input (samples, time steps, features)
train_features_reshaped = train_features.reshape((train_features.shape[0], 1, train_features.shape[1]))

# Model definition
model = Sequential([
    # Bidirectional LSTM layer
    Bidirectional(LSTM(200, return_sequences=True, input_shape=(train_features_reshaped.shape[1], train_features_reshaped.shape[2]))),
    Dropout(0.2),  # Dropout for regularization
    LSTM(100),      # Second LSTM layer
    Dropout(0.2),  # Another Dropout layer
    Dense(10, activation='relu', kernel_regularizer=l2(0.01)),  # Dense layer with L2 regularization
    Dense(1, activation='linear')  # Output layer for regression
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mean_squared_error', metrics=['mean_absolute_error'])



# Model training
history = model.fit(
    train_features_reshaped,
    train_labels,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    # callbacks=[early_stopping, model_checkpoint],
    verbose=2
)


# Model evaluation (assuming 'test_features' and 'test_labels' are your test datasets)
test_features_reshaped = test_features.reshape((test_features.shape[0], 1, test_features.shape[1]))
test_loss, test_mae = model.evaluate(test_features_reshaped, test_labels, verbose=2)

print(f'Test Loss: {test_loss}, Test MAE: {test_mae}')

# Optionally plot the history for loss and validation loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# C:\Users\Madusanka(MadusankaB\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 - 13s - 703ms/step - loss: 11.4813 - mean_absolute_error: 2.9037 - val_loss: 17.4102 - val_mean_absolute_error: 3.5665
# Epoch 2/100
# 18/18 - 0s - 16ms/step - loss: 11.3935 - mean_absolute_error: 2.8910 - val_loss: 17.2783 - val_mean_absolute_error: 3.5499
# Epoch 3/100
# 18/18 - 0s - 16ms/step - loss: 11.3153 - mean_absolute_error: 2.8792 - val_loss: 17.1320 - val_mean_absolute_error: 3.5315
# Epoch 4/100
# 18/18 - 0s - 15ms/step - loss: 11.2327 - mean_absolute_error: 2.8673 - val_loss: 16.9797 - val_mean_absolute_error: 3.5122
# Epoch 5/100
# 18/18 - 0s - 16ms/step - loss: 11.1505 - mean_absolute_error: 2.8549 - val_loss: 16.8089 - val_mean_absolute_error: 3.4901
# Epoch 6/100
# 18/18 - 0s - 16ms/step - loss: 11.0498 - mean_absolute_error: 2.8401 - val_loss: 16.6133 - val_mean_absolute_error: 3.4646
# Epoch 7/100
# 18/18 - 0s - 16ms/step - loss: 10.9464 - mean_absolute_error: 2.8237 - val_loss: 16.3873 - val_mean_absolute_error: 3.4346
# Epoch 8/100
# 18/18 - 0s - 15ms/step - loss: 10.8287 - mean_absolute_error: 2.8067 - val_loss: 16.1190 - val_mean_absolute_error: 3.3983
# Epoch 9/100
# 18/18 - 0s - 15ms/step - loss: 10.6721 - mean_absolute_error: 2.7828 - val_loss: 15.7929 - val_mean_absolute_error: 3.3528
# Epoch 10/100
# 18/18 - 0s - 15ms/step - loss: 10.5155 - mean_absolute_error: 2.7588 - val_loss: 15.4171 - val_mean_absolute_error: 3.2989
# Epoch 11/100
# 18/18 - 0s - 14ms/step - loss: 10.3156 - mean_absolute_error: 2.7283 - val_loss: 15.0076 - val_mean_absolute_error: 3.2377
# Epoch 12/100
# 18/18 - 0s - 14ms/step - loss: 10.0974 - mean_absolute_error: 2.6914 - val_loss: 14.4841 - val_mean_absolute_error: 3.1552
# Epoch 13/100
# 18/18 - 0s - 16ms/step - loss: 9.7963 - mean_absolute_error: 2.6419 - val_loss: 13.8920 - val_mean_absolute_error: 3.0577
# Epoch 14/100
# 18/18 - 0s - 18ms/step - loss: 9.5142 - mean_absolute_error: 2.5899 - val_loss: 13.2539 - val_mean_absolute_error: 2.9645
# Epoch 15/100
# 18/18 - 0s - 15ms/step - loss: 9.1763 - mean_absolute_error: 2.5275 - val_loss: 12.5529 - val_mean_absolute_error: 2.8678
# Epoch 16/100
# 18/18 - 0s - 16ms/step - loss: 8.7513 - mean_absolute_error: 2.4580 - val_loss: 11.9063 - val_mean_absolute_error: 2.7874
# Epoch 17/100
# 18/18 - 0s - 16ms/step - loss: 8.4090 - mean_absolute_error: 2.3788 - val_loss: 11.3142 - val_mean_absolute_error: 2.7009
# Epoch 18/100
# 18/18 - 0s - 15ms/step - loss: 7.9867 - mean_absolute_error: 2.3050 - val_loss: 10.7912 - val_mean_absolute_error: 2.6242
# Epoch 19/100
# 18/18 - 0s - 15ms/step - loss: 7.5978 - mean_absolute_error: 2.2194 - val_loss: 10.3941 - val_mean_absolute_error: 2.5724
# Epoch 20/100
# 18/18 - 0s - 15ms/step - loss: 7.3025 - mean_absolute_error: 2.1605 - val_loss: 10.1331 - val_mean_absolute_error: 2.5212
# Epoch 21/100
# 18/18 - 0s - 15ms/step - loss: 7.0374 - mean_absolute_error: 2.1138 - val_loss: 9.9707 - val_mean_absolute_error: 2.4826
# Epoch 22/100
# 18/18 - 0s - 15ms/step - loss: 6.8101 - mean_absolute_error: 2.0595 - val_loss: 9.8709 - val_mean_absolute_error: 2.4673
# Epoch 23/100
# 18/18 - 0s - 16ms/step - loss: 6.6601 - mean_absolute_error: 2.0318 - val_loss: 9.7725 - val_mean_absolute_error: 2.4497
# Epoch 24/100
# 18/18 - 0s - 15ms/step - loss: 6.4589 - mean_absolute_error: 2.0020 - val_loss: 9.6373 - val_mean_absolute_error: 2.4330
# Epoch 25/100
# 18/18 - 0s - 15ms/step - loss: 6.2346 - mean_absolute_error: 1.9604 - val_loss: 9.5382 - val_mean_absolute_error: 2.4206
# Epoch 26/100
# 18/18 - 0s - 16ms/step - loss: 6.1090 - mean_absolute_error: 1.9267 - val_loss: 9.3550 - val_mean_absolute_error: 2.3978
# Epoch 27/100
# 18/18 - 0s - 16ms/step - loss: 5.9765 - mean_absolute_error: 1.9016 - val_loss: 9.1347 - val_mean_absolute_error: 2.3705
# Epoch 28/100
# 18/18 - 0s - 22ms/step - loss: 5.7580 - mean_absolute_error: 1.8511 - val_loss: 8.9642 - val_mean_absolute_error: 2.3455
# Epoch 29/100
# 18/18 - 0s - 16ms/step - loss: 5.5200 - mean_absolute_error: 1.8123 - val_loss: 8.7872 - val_mean_absolute_error: 2.3182
# Epoch 30/100
# 18/18 - 0s - 16ms/step - loss: 5.3229 - mean_absolute_error: 1.7696 - val_loss: 8.5559 - val_mean_absolute_error: 2.2797
# Epoch 31/100
# 18/18 - 0s - 17ms/step - loss: 5.0132 - mean_absolute_error: 1.7156 - val_loss: 8.3263 - val_mean_absolute_error: 2.2380
# Epoch 32/100
# 18/18 - 0s - 15ms/step - loss: 4.9313 - mean_absolute_error: 1.6773 - val_loss: 8.0785 - val_mean_absolute_error: 2.1938
# Epoch 33/100
# 18/18 - 0s - 18ms/step - loss: 4.6315 - mean_absolute_error: 1.6175 - val_loss: 7.7212 - val_mean_absolute_error: 2.1328
# Epoch 34/100
# 18/18 - 0s - 15ms/step - loss: 4.2535 - mean_absolute_error: 1.5320 - val_loss: 7.3676 - val_mean_absolute_error: 2.0671
# Epoch 35/100
# 18/18 - 0s - 15ms/step - loss: 4.0101 - mean_absolute_error: 1.4700 - val_loss: 6.9574 - val_mean_absolute_error: 1.9853
# Epoch 36/100
# 18/18 - 0s - 16ms/step - loss: 3.6985 - mean_absolute_error: 1.3862 - val_loss: 6.5076 - val_mean_absolute_error: 1.8878
# Epoch 37/100
# 18/18 - 0s - 16ms/step - loss: 3.3907 - mean_absolute_error: 1.3062 - val_loss: 6.1732 - val_mean_absolute_error: 1.8353
# Epoch 38/100
# 18/18 - 0s - 15ms/step - loss: 3.1332 - mean_absolute_error: 1.2269 - val_loss: 5.8510 - val_mean_absolute_error: 1.7908
# Epoch 39/100
# 18/18 - 0s - 16ms/step - loss: 2.9120 - mean_absolute_error: 1.1802 - val_loss: 5.6130 - val_mean_absolute_error: 1.7728
# Epoch 40/100
# 18/18 - 0s - 15ms/step - loss: 2.7819 - mean_absolute_error: 1.1624 - val_loss: 5.4487 - val_mean_absolute_error: 1.7638
# Epoch 41/100
# 18/18 - 0s - 17ms/step - loss: 2.7344 - mean_absolute_error: 1.1717 - val_loss: 5.3535 - val_mean_absolute_error: 1.7578
# Epoch 42/100
# 18/18 - 0s - 14ms/step - loss: 2.7289 - mean_absolute_error: 1.1779 - val_loss: 5.2358 - val_mean_absolute_error: 1.7446
# Epoch 43/100
# 18/18 - 0s - 16ms/step - loss: 2.6574 - mean_absolute_error: 1.1634 - val_loss: 5.1225 - val_mean_absolute_error: 1.7316
# Epoch 44/100
# 18/18 - 0s - 16ms/step - loss: 2.6573 - mean_absolute_error: 1.1836 - val_loss: 5.0491 - val_mean_absolute_error: 1.7229
# Epoch 45/100
# 18/18 - 0s - 15ms/step - loss: 2.5652 - mean_absolute_error: 1.1802 - val_loss: 5.0262 - val_mean_absolute_error: 1.7271
# Epoch 46/100
# 18/18 - 0s - 14ms/step - loss: 2.5419 - mean_absolute_error: 1.1908 - val_loss: 5.0004 - val_mean_absolute_error: 1.7244
# Epoch 47/100
# 18/18 - 0s - 18ms/step - loss: 2.5525 - mean_absolute_error: 1.1817 - val_loss: 4.9778 - val_mean_absolute_error: 1.7243
# Epoch 48/100
# 18/18 - 0s - 16ms/step - loss: 2.5099 - mean_absolute_error: 1.1716 - val_loss: 4.9794 - val_mean_absolute_error: 1.7216
# Epoch 49/100
# 18/18 - 0s - 18ms/step - loss: 2.6060 - mean_absolute_error: 1.2013 - val_loss: 4.9380 - val_mean_absolute_error: 1.7174
# Epoch 50/100
# 18/18 - 0s - 16ms/step - loss: 2.5194 - mean_absolute_error: 1.1750 - val_loss: 4.9292 - val_mean_absolute_error: 1.7193
# Epoch 51/100
# 18/18 - 0s - 15ms/step - loss: 2.5594 - mean_absolute_error: 1.2006 - val_loss: 4.9152 - val_mean_absolute_error: 1.7209
# Epoch 52/100
# 18/18 - 0s - 16ms/step - loss: 2.5551 - mean_absolute_error: 1.2005 - val_loss: 4.8976 - val_mean_absolute_error: 1.7197
# Epoch 53/100
# 18/18 - 0s - 16ms/step - loss: 2.5812 - mean_absolute_error: 1.2008 - val_loss: 4.8743 - val_mean_absolute_error: 1.7207
# Epoch 54/100
# 18/18 - 0s - 24ms/step - loss: 2.6269 - mean_absolute_error: 1.2121 - val_loss: 4.8661 - val_mean_absolute_error: 1.7178
# Epoch 55/100
# 18/18 - 0s - 15ms/step - loss: 2.6127 - mean_absolute_error: 1.2057 - val_loss: 4.8534 - val_mean_absolute_error: 1.7153
# Epoch 56/100
# 18/18 - 0s - 16ms/step - loss: 2.5481 - mean_absolute_error: 1.1927 - val_loss: 4.8290 - val_mean_absolute_error: 1.7096
# Epoch 57/100
# 18/18 - 0s - 16ms/step - loss: 2.4915 - mean_absolute_error: 1.1844 - val_loss: 4.8226 - val_mean_absolute_error: 1.7116
# Epoch 58/100
# 18/18 - 0s - 16ms/step - loss: 2.6242 - mean_absolute_error: 1.2221 - val_loss: 4.8383 - val_mean_absolute_error: 1.7103
# Epoch 59/100
# 18/18 - 0s - 15ms/step - loss: 2.4946 - mean_absolute_error: 1.1755 - val_loss: 4.8178 - val_mean_absolute_error: 1.7075
# Epoch 60/100
# 18/18 - 0s - 15ms/step - loss: 2.5474 - mean_absolute_error: 1.1993 - val_loss: 4.7980 - val_mean_absolute_error: 1.7079
# Epoch 61/100
# 18/18 - 0s - 16ms/step - loss: 2.5341 - mean_absolute_error: 1.1900 - val_loss: 4.7837 - val_mean_absolute_error: 1.7018
# Epoch 62/100
# 18/18 - 0s - 15ms/step - loss: 2.5429 - mean_absolute_error: 1.1831 - val_loss: 4.7821 - val_mean_absolute_error: 1.7006
# Epoch 63/100
# 18/18 - 0s - 16ms/step - loss: 2.5522 - mean_absolute_error: 1.2018 - val_loss: 4.7675 - val_mean_absolute_error: 1.7006
# Epoch 64/100
# 18/18 - 0s - 17ms/step - loss: 2.5534 - mean_absolute_error: 1.2054 - val_loss: 4.7536 - val_mean_absolute_error: 1.7025
# Epoch 65/100
# 18/18 - 0s - 16ms/step - loss: 2.4922 - mean_absolute_error: 1.1883 - val_loss: 4.7410 - val_mean_absolute_error: 1.6959
# Epoch 66/100
# 18/18 - 0s - 15ms/step - loss: 2.5542 - mean_absolute_error: 1.1995 - val_loss: 4.7320 - val_mean_absolute_error: 1.6984
# Epoch 67/100
# 18/18 - 1s - 29ms/step - loss: 2.4865 - mean_absolute_error: 1.1679 - val_loss: 4.7245 - val_mean_absolute_error: 1.6944
# Epoch 68/100
# 18/18 - 1s - 31ms/step - loss: 2.5374 - mean_absolute_error: 1.1894 - val_loss: 4.7221 - val_mean_absolute_error: 1.6924
# Epoch 69/100
# 18/18 - 0s - 19ms/step - loss: 2.4684 - mean_absolute_error: 1.1655 - val_loss: 4.7197 - val_mean_absolute_error: 1.6870
# Epoch 70/100
# 18/18 - 0s - 19ms/step - loss: 2.4554 - mean_absolute_error: 1.1718 - val_loss: 4.6961 - val_mean_absolute_error: 1.6853
# Epoch 71/100
# 18/18 - 1s - 34ms/step - loss: 2.4363 - mean_absolute_error: 1.1613 - val_loss: 4.6787 - val_mean_absolute_error: 1.6839
# Epoch 72/100
# 18/18 - 0s - 20ms/step - loss: 2.4841 - mean_absolute_error: 1.1962 - val_loss: 4.6840 - val_mean_absolute_error: 1.6836
# Epoch 73/100
# 18/18 - 1s - 34ms/step - loss: 2.5223 - mean_absolute_error: 1.1872 - val_loss: 4.6870 - val_mean_absolute_error: 1.6805
# Epoch 74/100
# 18/18 - 0s - 15ms/step - loss: 2.5569 - mean_absolute_error: 1.2157 - val_loss: 4.6800 - val_mean_absolute_error: 1.6805
# Epoch 75/100
# 18/18 - 0s - 21ms/step - loss: 2.5056 - mean_absolute_error: 1.2020 - val_loss: 4.6585 - val_mean_absolute_error: 1.6791
# Epoch 76/100
# 18/18 - 0s - 21ms/step - loss: 2.5075 - mean_absolute_error: 1.1956 - val_loss: 4.6733 - val_mean_absolute_error: 1.6801
# Epoch 77/100
# 18/18 - 0s - 21ms/step - loss: 2.5205 - mean_absolute_error: 1.1880 - val_loss: 4.6656 - val_mean_absolute_error: 1.6768
# Epoch 78/100
# 18/18 - 1s - 34ms/step - loss: 2.5134 - mean_absolute_error: 1.1823 - val_loss: 4.6637 - val_mean_absolute_error: 1.6708
# Epoch 79/100
# 18/18 - 0s - 18ms/step - loss: 2.5144 - mean_absolute_error: 1.1870 - val_loss: 4.6609 - val_mean_absolute_error: 1.6679
# Epoch 80/100
# 18/18 - 0s - 17ms/step - loss: 2.5021 - mean_absolute_error: 1.1830 - val_loss: 4.6548 - val_mean_absolute_error: 1.6714
# Epoch 81/100
# 18/18 - 0s - 17ms/step - loss: 2.4912 - mean_absolute_error: 1.1742 - val_loss: 4.6420 - val_mean_absolute_error: 1.6687
# Epoch 82/100
# 18/18 - 0s - 16ms/step - loss: 2.5337 - mean_absolute_error: 1.2076 - val_loss: 4.6342 - val_mean_absolute_error: 1.6723
# Epoch 83/100
# 18/18 - 0s - 15ms/step - loss: 2.5511 - mean_absolute_error: 1.2051 - val_loss: 4.6432 - val_mean_absolute_error: 1.6715
# Epoch 84/100
# 18/18 - 0s - 18ms/step - loss: 2.5038 - mean_absolute_error: 1.1769 - val_loss: 4.6332 - val_mean_absolute_error: 1.6700
# Epoch 85/100
# 18/18 - 0s - 15ms/step - loss: 2.4178 - mean_absolute_error: 1.1656 - val_loss: 4.6320 - val_mean_absolute_error: 1.6717
# Epoch 86/100
# 18/18 - 0s - 15ms/step - loss: 2.5315 - mean_absolute_error: 1.1904 - val_loss: 4.6439 - val_mean_absolute_error: 1.6751
# Epoch 87/100
# 18/18 - 0s - 15ms/step - loss: 2.4937 - mean_absolute_error: 1.1776 - val_loss: 4.6460 - val_mean_absolute_error: 1.6736
# Epoch 88/100
# 18/18 - 0s - 23ms/step - loss: 2.4464 - mean_absolute_error: 1.1772 - val_loss: 4.6417 - val_mean_absolute_error: 1.6706
# Epoch 89/100
# 18/18 - 0s - 20ms/step - loss: 2.4197 - mean_absolute_error: 1.1710 - val_loss: 4.6268 - val_mean_absolute_error: 1.6689
# Epoch 90/100
# 18/18 - 0s - 25ms/step - loss: 2.4586 - mean_absolute_error: 1.1702 - val_loss: 4.6185 - val_mean_absolute_error: 1.6648
# Epoch 91/100
# 18/18 - 0s - 15ms/step - loss: 2.4903 - mean_absolute_error: 1.1840 - val_loss: 4.6211 - val_mean_absolute_error: 1.6646
# Epoch 92/100
# 18/18 - 0s - 15ms/step - loss: 2.3892 - mean_absolute_error: 1.1558 - val_loss: 4.5987 - val_mean_absolute_error: 1.6669
# Epoch 93/100
# 18/18 - 0s - 16ms/step - loss: 2.4268 - mean_absolute_error: 1.1782 - val_loss: 4.5729 - val_mean_absolute_error: 1.6656
# Epoch 94/100
# 18/18 - 0s - 15ms/step - loss: 2.4587 - mean_absolute_error: 1.1861 - val_loss: 4.5700 - val_mean_absolute_error: 1.6670
# Epoch 95/100
# 18/18 - 0s - 18ms/step - loss: 2.4784 - mean_absolute_error: 1.1845 - val_loss: 4.5733 - val_mean_absolute_error: 1.6645
# Epoch 96/100
# 18/18 - 0s - 15ms/step - loss: 2.4372 - mean_absolute_error: 1.1635 - val_loss: 4.5749 - val_mean_absolute_error: 1.6498
# Epoch 97/100
# 18/18 - 0s - 16ms/step - loss: 2.4306 - mean_absolute_error: 1.1648 - val_loss: 4.5518 - val_mean_absolute_error: 1.6540
# Epoch 98/100
# 18/18 - 0s - 18ms/step - loss: 2.4869 - mean_absolute_error: 1.1907 - val_loss: 4.5537 - val_mean_absolute_error: 1.6567
# Epoch 99/100
# 18/18 - 0s - 21ms/step - loss: 2.5139 - mean_absolute_error: 1.2044 - val_loss: 4.5696 - val_mean_absolute_error: 1.6520
# Epoch 100/100
# 18/18 - 0s - 22ms/step - loss: 2.4470 - mean_absolute_error: 1.1724 - val_loss: 4.5735 - val_mean_absolute_error: 1.6459
# 3/3 - 0s - 21ms/step - loss: 3.6488 - mean_absolute_error: 1.5038
# Test Loss: 3.6487984657287598, Test MAE: 1.50376558303833

# %%
# save the model
model.save('river_height_prediction_rathnapura_model.keras')

# %%
#load the model
from tensorflow.keras.models import load_model

model = load_model('river_height_prediction_ellagawa_model.keras')

# Predictions
predictions = model.predict(test_features_reshaped)

# Plotting the predictions
plt.figure(figsize=(12, 6))
plt.plot(test_data['Date'], test_data['river_height'], label='Actual')
plt.plot(test_data['Date'], predictions, label='Predicted')
plt.title('River Height Prediction')
plt.xlabel('Date')
plt.ylabel('River Height (m)')
plt.legend()
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 669ms/step

# %%
import requests

# URL of the FastAPI endpoint
url = 'http://127.0.0.1:8000/forecast/rathnapura/'

# Data to be sent to the API
data = {
    "current_height": 2.5,
    "current_rainfall": 10.0
}

# Make the POST request and store the response
response = requests.post(url, json=data)

# Print the status code and the response data
print(f"Status Code: {response.status_code}")
print("Response Data:", response.json())
