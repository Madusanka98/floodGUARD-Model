# %%
import pandas as pd

data = pd.read_csv('rainfall-riverheight-history-Rathnapura.csv')

data.head()
# Out:
#         Date      station  river_hight  rainfall
# 0  6/14/2024    Putupaula         0.75       1.4
# 1  6/14/2024     Ellagawa         5.25       0.0
# 2  6/14/2024   Rathnapura         1.38       0.0
# 3  6/14/2024       Magura         1.75       0.0
# 4  6/14/2024  Kalawellawa         2.47       0.0

# %%
rathnapura_data = data[data['station'] == 'Ellagawa']

# Convert 'Date' to datetime format
rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])

# Convert 'Date' to datetime format
rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])

# Check the processed data and look for missing values
rathnapura_data.info(), rathnapura_data.head()

# Filter the data for the "Rathnapura" station and sort by date
rathnapura_data = data[data['station'] == 'Ellagawa'].sort_values('Date')


#rename river height column as 'river_height'
rathnapura_data.rename(columns={'river_hight': 'river_height'}, inplace=True)


rathnapura_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 436 entries, 1 to 2103
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         436 non-null    datetime64[ns]
#  1   station      436 non-null    object
#  2   river_hight  435 non-null    float64
#  3   rainfall     435 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 17.0+ KB
# C:\Users\Madusanka(MadusankaB\AppData\Local\Temp\ipykernel_20472\3895121739.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])
# C:\Users\Madusanka(MadusankaB\AppData\Local\Temp\ipykernel_20472\3895121739.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rathnapura_data['Date'] = pd.to_datetime(rathnapura_data['Date'])
#            Date   station  river_height  rainfall
# 291    1/1/2024  Ellagawa          5.59      70.7
# 1371  1/10/2022  Ellagawa          5.40      22.1
# 246   1/10/2024  Ellagawa          5.49       0.5
# 241   1/11/2024  Ellagawa          5.13       2.7
# 236   1/12/2024  Ellagawa          4.87       0.0

# %%
# remove outliers
rathnapura_data = rathnapura_data[rathnapura_data['rainfall'] < 200]

# add rolling mean to missing values
rathnapura_data['rainfall'] = rathnapura_data['rainfall'].fillna(rathnapura_data['rainfall'].rolling(30, min_periods=1).mean())

# #fill missing values with the mean of the monthly rainfall for each month
# rathnapura_data['rainfall'] = rathnapura_data.groupby(rathnapura_data['Date'].dt.month)['rainfall'].transform(lambda x: x.fillna(x.mean()))

# plot the data
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(rathnapura_data['Date'], rathnapura_data['rainfall'], label='Rainfall')
plt.title('Rainfall in Ellagawa')
plt.xlabel('Date')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.show()

# %%
#remove outliers
rathnapura_data = rathnapura_data[rathnapura_data['river_height'] < 10]

#add rolling mean to missing values
rathnapura_data['river_height'] = rathnapura_data['river_height'].fillna(rathnapura_data['river_height'].rolling(30, min_periods=1).mean())


#plot river height
plt.figure(figsize=(12, 6))
plt.plot(rathnapura_data['Date'], rathnapura_data['river_height'], label='River Height')
plt.title('River Height in Ellagawa')
plt.xlabel('Date')
plt.ylabel('River Height (m)')
plt.legend()
plt.show()

# %%
# Creating lagged features for river height and rainfall
for lag in range(1, 4):
    rathnapura_data[f'river_height_lag_{lag}'] = rathnapura_data['river_height'].shift(lag)
    rathnapura_data[f'rainfall_lag_{lag}'] = rathnapura_data['rainfall'].shift(lag)

# Dropping rows with missing values that result from lagging
rathnapura_data.dropna(inplace=True)

# Splitting the data into train and test sets
# Let's use the last 20% of the data as test set
split_index = int(len(rathnapura_data) * 0.8)
train_data = rathnapura_data.iloc[:split_index]
test_data = rathnapura_data.iloc[split_index:]

# Show the structure of the dataset with new features and the split
train_data.info(), test_data.info(), train_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 328 entries, 241 to 2007
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                328 non-null    object
#  1   station             328 non-null    object
#  2   river_height        328 non-null    float64
#  3   rainfall            328 non-null    float64
#  4   river_height_lag_1  328 non-null    float64
#  5   rainfall_lag_1      328 non-null    float64
#  6   river_height_lag_2  328 non-null    float64
#  7   rainfall_lag_2      328 non-null    float64
#  8   river_height_lag_3  328 non-null    float64
#  9   rainfall_lag_3      328 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 28.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 1616 to 676
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                83 non-null     object
#  1   station             83 non-null     object
#  2   river_height        83 non-null     float64
#  3   rainfall            83 non-null     float64
#  4   river_height_lag_1  83 non-null     float64
#  5   rainfall_lag_1      83 non-null     float64
#  6   river_height_lag_2  83 non-null     float64
#  7   rainfall_lag_2      83 non-null     float64
#  8   river_height_lag_3  83 non-null     float64
#  9   rainfall_lag_3      83 non-null     float64
# dtypes: float64(8), object(2)
# memory usage: 7.1+ KB
# (None,
#  None,
#             Date   station  river_height  rainfall  river_height_lag_1  \
#  241   1/11/2024  Ellagawa          5.13       2.7                5.49
#  236   1/12/2024  Ellagawa          4.87       0.0                5.13
#  1366  1/13/2022  Ellagawa          4.40       0.0                4.87
#  231   1/13/2024  Ellagawa          4.67       0.0                4.40
#  226   1/14/2024  Ellagawa          4.55       0.0                4.67
#
#        rainfall_lag_1  river_height_lag_2  rainfall_lag_2  river_height_lag_3  \
#  241              0.5                5.40            22.1                5.59
#  236              2.7                5.49             0.5                5.40
#  1366             0.0                5.13             2.7                5.49
#  231              0.0                4.87             0.0                5.13
#  226              0.0                4.40             0.0                4.87
#
#        rainfall_lag_3
#  241             70.7
#  236             22.1
#  1366             0.5
#  231              2.7
#  226              0.0  )

# %%
from sklearn.preprocessing import StandardScaler

# Features and target variable
features = ['river_height_lag_1', 'rainfall_lag_1', 'river_height_lag_2', 'rainfall_lag_2', 'river_height_lag_3', 'rainfall_lag_3']
target = 'river_height'

# Standardizing the features
scaler = StandardScaler()
train_features = scaler.fit_transform(train_data[features])
test_features = scaler.transform(test_data[features])

train_labels = train_data[target]
test_labels = test_data[target]

# Check the first few rows to see the scaling
train_features[:5], train_labels.head()
# Out:
# (array([[-0.78615302, -0.75003083, -0.8398465 , -0.03762517, -0.72098294,
#           1.55370333],
#         [-1.01877205, -0.67747509, -0.78174144, -0.74998967, -0.84393179,
#          -0.04450496],
#         [-1.18677468, -0.76652077, -1.0141617 , -0.67743403, -0.78569287,
#          -0.75481976],
#         [-1.49047174, -0.76652077, -1.18202077, -0.76647959, -1.01864858,
#          -0.68247288],
#         [-1.31600747, -0.76652077, -1.48545833, -0.76647959, -1.18689437,
#          -0.77126223]]),
#  241     5.13
#  236     4.87
#  1366    4.40
#  231     4.67
#  226     4.55
#  Name: river_height, dtype: float64)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Assuming 'train_features' and 'train_labels' are your training datasets
# Reshape features for LSTM input (samples, time steps, features)
train_features_reshaped = train_features.reshape((train_features.shape[0], 1, train_features.shape[1]))

# Model definition
model = Sequential([
    # Bidirectional LSTM layer
    Bidirectional(LSTM(200, return_sequences=True, input_shape=(train_features_reshaped.shape[1], train_features_reshaped.shape[2]))),
    Dropout(0.2),  # Dropout for regularization
    LSTM(100),      # Second LSTM layer
    Dropout(0.2),  # Another Dropout layer
    Dense(10, activation='relu', kernel_regularizer=l2(0.01)),  # Dense layer with L2 regularization
    Dense(1, activation='linear')  # Output layer for regression
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mean_squared_error', metrics=['mean_absolute_error'])



# Model training
history = model.fit(
    train_features_reshaped,
    train_labels,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    # callbacks=[early_stopping, model_checkpoint],
    verbose=2
)


# Model evaluation (assuming 'test_features' and 'test_labels' are your test datasets)
test_features_reshaped = test_features.reshape((test_features.shape[0], 1, test_features.shape[1]))
test_loss, test_mae = model.evaluate(test_features_reshaped, test_labels, verbose=2)

print(f'Test Loss: {test_loss}, Test MAE: {test_mae}')

# Optionally plot the history for loss and validation loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# C:\Users\Madusanka(MadusankaB\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 - 11s - 646ms/step - loss: 46.4405 - mean_absolute_error: 6.6296 - val_loss: 51.3124 - val_mean_absolute_error: 6.9660
# Epoch 2/100
# 17/17 - 0s - 16ms/step - loss: 46.0943 - mean_absolute_error: 6.6045 - val_loss: 50.9817 - val_mean_absolute_error: 6.9426
# Epoch 3/100
# 17/17 - 0s - 18ms/step - loss: 45.7842 - mean_absolute_error: 6.5825 - val_loss: 50.6235 - val_mean_absolute_error: 6.9172
# Epoch 4/100
# 17/17 - 0s - 16ms/step - loss: 45.4226 - mean_absolute_error: 6.5560 - val_loss: 50.2127 - val_mean_absolute_error: 6.8879
# Epoch 5/100
# 17/17 - 0s - 15ms/step - loss: 44.9674 - mean_absolute_error: 6.5241 - val_loss: 49.7632 - val_mean_absolute_error: 6.8557
# Epoch 6/100
# 17/17 - 0s - 16ms/step - loss: 44.4770 - mean_absolute_error: 6.4890 - val_loss: 49.2188 - val_mean_absolute_error: 6.8163
# Epoch 7/100
# 17/17 - 0s - 20ms/step - loss: 43.9326 - mean_absolute_error: 6.4498 - val_loss: 48.5868 - val_mean_absolute_error: 6.7702
# Epoch 8/100
# 17/17 - 0s - 13ms/step - loss: 43.3080 - mean_absolute_error: 6.4035 - val_loss: 47.8372 - val_mean_absolute_error: 6.7148
# Epoch 9/100
# 17/17 - 0s - 14ms/step - loss: 42.5533 - mean_absolute_error: 6.3485 - val_loss: 46.9408 - val_mean_absolute_error: 6.6475
# Epoch 10/100
# 17/17 - 0s - 16ms/step - loss: 41.5576 - mean_absolute_error: 6.2738 - val_loss: 45.9041 - val_mean_absolute_error: 6.5680
# Epoch 11/100
# 17/17 - 0s - 18ms/step - loss: 40.5181 - mean_absolute_error: 6.1942 - val_loss: 44.5707 - val_mean_absolute_error: 6.4628
# Epoch 12/100
# 17/17 - 0s - 15ms/step - loss: 39.0524 - mean_absolute_error: 6.0804 - val_loss: 43.0633 - val_mean_absolute_error: 6.3396
# Epoch 13/100
# 17/17 - 0s - 13ms/step - loss: 37.3993 - mean_absolute_error: 5.9429 - val_loss: 41.2230 - val_mean_absolute_error: 6.1812
# Epoch 14/100
# 17/17 - 0s - 13ms/step - loss: 35.6215 - mean_absolute_error: 5.7863 - val_loss: 39.1078 - val_mean_absolute_error: 5.9870
# Epoch 15/100
# 17/17 - 0s - 13ms/step - loss: 33.5125 - mean_absolute_error: 5.5863 - val_loss: 36.8913 - val_mean_absolute_error: 5.7651
# Epoch 16/100
# 17/17 - 0s - 13ms/step - loss: 31.4781 - mean_absolute_error: 5.3724 - val_loss: 34.5623 - val_mean_absolute_error: 5.5379
# Epoch 17/100
# 17/17 - 0s - 15ms/step - loss: 29.5169 - mean_absolute_error: 5.1643 - val_loss: 32.3616 - val_mean_absolute_error: 5.3285
# Epoch 18/100
# 17/17 - 0s - 13ms/step - loss: 27.5514 - mean_absolute_error: 4.9177 - val_loss: 30.2818 - val_mean_absolute_error: 5.1000
# Epoch 19/100
# 17/17 - 0s - 13ms/step - loss: 25.9512 - mean_absolute_error: 4.7077 - val_loss: 28.4313 - val_mean_absolute_error: 4.8622
# Epoch 20/100
# 17/17 - 0s - 13ms/step - loss: 24.4174 - mean_absolute_error: 4.5030 - val_loss: 26.8819 - val_mean_absolute_error: 4.6586
# Epoch 21/100
# 17/17 - 0s - 13ms/step - loss: 23.3884 - mean_absolute_error: 4.3644 - val_loss: 25.6685 - val_mean_absolute_error: 4.5107
# Epoch 22/100
# 17/17 - 0s - 13ms/step - loss: 22.3309 - mean_absolute_error: 4.2115 - val_loss: 24.5152 - val_mean_absolute_error: 4.3667
# Epoch 23/100
# 17/17 - 0s - 13ms/step - loss: 21.6200 - mean_absolute_error: 4.1227 - val_loss: 23.5249 - val_mean_absolute_error: 4.2436
# Epoch 24/100
# 17/17 - 0s - 14ms/step - loss: 20.4912 - mean_absolute_error: 4.0021 - val_loss: 22.6019 - val_mean_absolute_error: 4.1255
# Epoch 25/100
# 17/17 - 0s - 15ms/step - loss: 19.6710 - mean_absolute_error: 3.9030 - val_loss: 21.7218 - val_mean_absolute_error: 4.0211
# Epoch 26/100
# 17/17 - 0s - 13ms/step - loss: 18.9083 - mean_absolute_error: 3.8060 - val_loss: 20.8487 - val_mean_absolute_error: 3.9249
# Epoch 27/100
# 17/17 - 0s - 13ms/step - loss: 18.0570 - mean_absolute_error: 3.7147 - val_loss: 19.9492 - val_mean_absolute_error: 3.8171
# Epoch 28/100
# 17/17 - 0s - 20ms/step - loss: 16.9861 - mean_absolute_error: 3.5890 - val_loss: 19.0696 - val_mean_absolute_error: 3.7155
# Epoch 29/100
# 17/17 - 0s - 15ms/step - loss: 16.3304 - mean_absolute_error: 3.4917 - val_loss: 18.1562 - val_mean_absolute_error: 3.6092
# Epoch 30/100
# 17/17 - 0s - 21ms/step - loss: 15.4043 - mean_absolute_error: 3.3864 - val_loss: 17.2694 - val_mean_absolute_error: 3.5019
# Epoch 31/100
# 17/17 - 0s - 17ms/step - loss: 14.4418 - mean_absolute_error: 3.2644 - val_loss: 16.3544 - val_mean_absolute_error: 3.3893
# Epoch 32/100
# 17/17 - 0s - 16ms/step - loss: 13.2119 - mean_absolute_error: 3.0922 - val_loss: 15.4077 - val_mean_absolute_error: 3.2715
# Epoch 33/100
# 17/17 - 0s - 17ms/step - loss: 12.5410 - mean_absolute_error: 2.9919 - val_loss: 14.4192 - val_mean_absolute_error: 3.1524
# Epoch 34/100
# 17/17 - 0s - 16ms/step - loss: 11.6170 - mean_absolute_error: 2.8730 - val_loss: 13.4968 - val_mean_absolute_error: 3.0413
# Epoch 35/100
# 17/17 - 0s - 17ms/step - loss: 10.4857 - mean_absolute_error: 2.6829 - val_loss: 12.5080 - val_mean_absolute_error: 2.9139
# Epoch 36/100
# 17/17 - 0s - 18ms/step - loss: 9.5286 - mean_absolute_error: 2.5634 - val_loss: 11.5259 - val_mean_absolute_error: 2.7813
# Epoch 37/100
# 17/17 - 0s - 19ms/step - loss: 8.3569 - mean_absolute_error: 2.3395 - val_loss: 10.5315 - val_mean_absolute_error: 2.6376
# Epoch 38/100
# 17/17 - 0s - 15ms/step - loss: 7.5415 - mean_absolute_error: 2.1939 - val_loss: 9.4933 - val_mean_absolute_error: 2.4790
# Epoch 39/100
# 17/17 - 0s - 16ms/step - loss: 6.5271 - mean_absolute_error: 2.0293 - val_loss: 8.5004 - val_mean_absolute_error: 2.3263
# Epoch 40/100
# 17/17 - 0s - 20ms/step - loss: 5.6429 - mean_absolute_error: 1.8645 - val_loss: 7.5510 - val_mean_absolute_error: 2.1828
# Epoch 41/100
# 17/17 - 0s - 19ms/step - loss: 4.5824 - mean_absolute_error: 1.6760 - val_loss: 6.7180 - val_mean_absolute_error: 2.0526
# Epoch 42/100
# 17/17 - 0s - 14ms/step - loss: 4.3328 - mean_absolute_error: 1.5940 - val_loss: 6.1412 - val_mean_absolute_error: 1.9536
# Epoch 43/100
# 17/17 - 0s - 15ms/step - loss: 3.8963 - mean_absolute_error: 1.4950 - val_loss: 5.6060 - val_mean_absolute_error: 1.8698
# Epoch 44/100
# 17/17 - 0s - 22ms/step - loss: 3.6061 - mean_absolute_error: 1.4646 - val_loss: 5.2556 - val_mean_absolute_error: 1.8238
# Epoch 45/100
# 17/17 - 0s - 18ms/step - loss: 3.2777 - mean_absolute_error: 1.3977 - val_loss: 4.9336 - val_mean_absolute_error: 1.7760
# Epoch 46/100
# 17/17 - 0s - 17ms/step - loss: 3.2575 - mean_absolute_error: 1.3748 - val_loss: 4.6805 - val_mean_absolute_error: 1.7365
# Epoch 47/100
# 17/17 - 0s - 19ms/step - loss: 2.9933 - mean_absolute_error: 1.3070 - val_loss: 4.4705 - val_mean_absolute_error: 1.7059
# Epoch 48/100
# 17/17 - 0s - 16ms/step - loss: 2.7562 - mean_absolute_error: 1.2731 - val_loss: 4.2975 - val_mean_absolute_error: 1.6764
# Epoch 49/100
# 17/17 - 0s - 21ms/step - loss: 2.8801 - mean_absolute_error: 1.2758 - val_loss: 4.1866 - val_mean_absolute_error: 1.6566
# Epoch 50/100
# 17/17 - 0s - 16ms/step - loss: 2.5943 - mean_absolute_error: 1.2266 - val_loss: 4.0867 - val_mean_absolute_error: 1.6375
# Epoch 51/100
# 17/17 - 0s - 15ms/step - loss: 2.6409 - mean_absolute_error: 1.2283 - val_loss: 3.9843 - val_mean_absolute_error: 1.6156
# Epoch 52/100
# 17/17 - 0s - 20ms/step - loss: 2.4767 - mean_absolute_error: 1.1847 - val_loss: 3.8710 - val_mean_absolute_error: 1.5928
# Epoch 53/100
# 17/17 - 0s - 15ms/step - loss: 2.5504 - mean_absolute_error: 1.2045 - val_loss: 3.8072 - val_mean_absolute_error: 1.5762
# Epoch 54/100
# 17/17 - 0s - 14ms/step - loss: 2.4414 - mean_absolute_error: 1.1826 - val_loss: 3.7218 - val_mean_absolute_error: 1.5608
# Epoch 55/100
# 17/17 - 0s - 14ms/step - loss: 2.3890 - mean_absolute_error: 1.1505 - val_loss: 3.6539 - val_mean_absolute_error: 1.5501
# Epoch 56/100
# 17/17 - 0s - 14ms/step - loss: 2.1948 - mean_absolute_error: 1.1083 - val_loss: 3.6035 - val_mean_absolute_error: 1.5431
# Epoch 57/100
# 17/17 - 0s - 17ms/step - loss: 2.3085 - mean_absolute_error: 1.1095 - val_loss: 3.5709 - val_mean_absolute_error: 1.5350
# Epoch 58/100
# 17/17 - 0s - 22ms/step - loss: 2.3237 - mean_absolute_error: 1.1290 - val_loss: 3.5139 - val_mean_absolute_error: 1.5263
# Epoch 59/100
# 17/17 - 0s - 19ms/step - loss: 2.1609 - mean_absolute_error: 1.1173 - val_loss: 3.4895 - val_mean_absolute_error: 1.5173
# Epoch 60/100
# 17/17 - 0s - 16ms/step - loss: 2.1934 - mean_absolute_error: 1.1319 - val_loss: 3.4492 - val_mean_absolute_error: 1.5045
# Epoch 61/100
# 17/17 - 0s - 15ms/step - loss: 2.2271 - mean_absolute_error: 1.0874 - val_loss: 3.4245 - val_mean_absolute_error: 1.5008
# Epoch 62/100
# 17/17 - 0s - 16ms/step - loss: 2.3397 - mean_absolute_error: 1.1612 - val_loss: 3.3690 - val_mean_absolute_error: 1.4950
# Epoch 63/100
# 17/17 - 0s - 18ms/step - loss: 2.1768 - mean_absolute_error: 1.0854 - val_loss: 3.3311 - val_mean_absolute_error: 1.4866
# Epoch 64/100
# 17/17 - 0s - 19ms/step - loss: 2.2109 - mean_absolute_error: 1.0807 - val_loss: 3.2887 - val_mean_absolute_error: 1.4820
# Epoch 65/100
# 17/17 - 1s - 32ms/step - loss: 2.2434 - mean_absolute_error: 1.0993 - val_loss: 3.2495 - val_mean_absolute_error: 1.4770
# Epoch 66/100
# 17/17 - 0s - 15ms/step - loss: 2.1631 - mean_absolute_error: 1.0711 - val_loss: 3.2548 - val_mean_absolute_error: 1.4739
# Epoch 67/100
# 17/17 - 0s - 18ms/step - loss: 2.2478 - mean_absolute_error: 1.1349 - val_loss: 3.2489 - val_mean_absolute_error: 1.4720
# Epoch 68/100
# 17/17 - 0s - 16ms/step - loss: 2.0235 - mean_absolute_error: 1.0411 - val_loss: 3.2341 - val_mean_absolute_error: 1.4713
# Epoch 69/100
# 17/17 - 0s - 17ms/step - loss: 2.1991 - mean_absolute_error: 1.0675 - val_loss: 3.2356 - val_mean_absolute_error: 1.4693
# Epoch 70/100
# 17/17 - 0s - 15ms/step - loss: 2.1280 - mean_absolute_error: 1.0843 - val_loss: 3.2109 - val_mean_absolute_error: 1.4676
# Epoch 71/100
# 17/17 - 0s - 14ms/step - loss: 2.1112 - mean_absolute_error: 1.0710 - val_loss: 3.2149 - val_mean_absolute_error: 1.4654
# Epoch 72/100
# 17/17 - 0s - 18ms/step - loss: 2.0785 - mean_absolute_error: 1.0859 - val_loss: 3.1910 - val_mean_absolute_error: 1.4616
# Epoch 73/100
# 17/17 - 0s - 17ms/step - loss: 2.0365 - mean_absolute_error: 1.0635 - val_loss: 3.1813 - val_mean_absolute_error: 1.4588
# Epoch 74/100
# 17/17 - 0s - 15ms/step - loss: 2.1027 - mean_absolute_error: 1.0803 - val_loss: 3.1626 - val_mean_absolute_error: 1.4567
# Epoch 75/100
# 17/17 - 0s - 20ms/step - loss: 2.0674 - mean_absolute_error: 1.0597 - val_loss: 3.1480 - val_mean_absolute_error: 1.4551
# Epoch 76/100
# 17/17 - 0s - 16ms/step - loss: 2.0260 - mean_absolute_error: 1.0453 - val_loss: 3.1562 - val_mean_absolute_error: 1.4558
# Epoch 77/100
# 17/17 - 0s - 14ms/step - loss: 2.2882 - mean_absolute_error: 1.1244 - val_loss: 3.1739 - val_mean_absolute_error: 1.4563
# Epoch 78/100
# 17/17 - 0s - 21ms/step - loss: 2.0546 - mean_absolute_error: 1.0671 - val_loss: 3.1622 - val_mean_absolute_error: 1.4542
# Epoch 79/100
# 17/17 - 0s - 15ms/step - loss: 2.0821 - mean_absolute_error: 1.0529 - val_loss: 3.1379 - val_mean_absolute_error: 1.4512
# Epoch 80/100
# 17/17 - 0s - 21ms/step - loss: 1.9474 - mean_absolute_error: 0.9991 - val_loss: 3.1254 - val_mean_absolute_error: 1.4500
# Epoch 81/100
# 17/17 - 0s - 19ms/step - loss: 2.0761 - mean_absolute_error: 1.1086 - val_loss: 3.1611 - val_mean_absolute_error: 1.4586
# Epoch 82/100
# 17/17 - 0s - 21ms/step - loss: 2.0409 - mean_absolute_error: 1.0453 - val_loss: 3.1622 - val_mean_absolute_error: 1.4604
# Epoch 83/100
# 17/17 - 0s - 17ms/step - loss: 1.9624 - mean_absolute_error: 1.0383 - val_loss: 3.1756 - val_mean_absolute_error: 1.4648
# Epoch 84/100
# 17/17 - 0s - 18ms/step - loss: 2.1179 - mean_absolute_error: 1.0619 - val_loss: 3.1549 - val_mean_absolute_error: 1.4578
# Epoch 85/100
# 17/17 - 0s - 14ms/step - loss: 2.0744 - mean_absolute_error: 1.0615 - val_loss: 3.1501 - val_mean_absolute_error: 1.4578
# Epoch 86/100
# 17/17 - 0s - 14ms/step - loss: 1.9373 - mean_absolute_error: 1.0350 - val_loss: 3.1355 - val_mean_absolute_error: 1.4574
# Epoch 87/100
# 17/17 - 0s - 13ms/step - loss: 2.1039 - mean_absolute_error: 1.0642 - val_loss: 3.1397 - val_mean_absolute_error: 1.4590
# Epoch 88/100
# 17/17 - 0s - 13ms/step - loss: 2.1099 - mean_absolute_error: 1.0744 - val_loss: 3.1312 - val_mean_absolute_error: 1.4584
# Epoch 89/100
# 17/17 - 0s - 14ms/step - loss: 2.0020 - mean_absolute_error: 1.0537 - val_loss: 3.1488 - val_mean_absolute_error: 1.4630
# Epoch 90/100
# 17/17 - 0s - 14ms/step - loss: 2.0708 - mean_absolute_error: 1.0685 - val_loss: 3.1268 - val_mean_absolute_error: 1.4580
# Epoch 91/100
# 17/17 - 0s - 15ms/step - loss: 1.9932 - mean_absolute_error: 1.0612 - val_loss: 3.1292 - val_mean_absolute_error: 1.4584
# Epoch 92/100
# 17/17 - 0s - 14ms/step - loss: 1.9515 - mean_absolute_error: 1.0374 - val_loss: 3.1188 - val_mean_absolute_error: 1.4556
# Epoch 93/100
# 17/17 - 0s - 14ms/step - loss: 1.8512 - mean_absolute_error: 1.0081 - val_loss: 3.1258 - val_mean_absolute_error: 1.4574
# Epoch 94/100
# 17/17 - 0s - 15ms/step - loss: 1.9997 - mean_absolute_error: 1.0410 - val_loss: 3.1292 - val_mean_absolute_error: 1.4571
# Epoch 95/100
# 17/17 - 0s - 15ms/step - loss: 2.0073 - mean_absolute_error: 1.0531 - val_loss: 3.0969 - val_mean_absolute_error: 1.4508
# Epoch 96/100
# 17/17 - 0s - 15ms/step - loss: 2.0691 - mean_absolute_error: 1.0912 - val_loss: 3.0894 - val_mean_absolute_error: 1.4466
# Epoch 97/100
# 17/17 - 0s - 15ms/step - loss: 1.8004 - mean_absolute_error: 0.9806 - val_loss: 3.1067 - val_mean_absolute_error: 1.4509
# Epoch 98/100
# 17/17 - 0s - 16ms/step - loss: 2.0821 - mean_absolute_error: 1.0826 - val_loss: 3.1158 - val_mean_absolute_error: 1.4524
# Epoch 99/100
# 17/17 - 0s - 15ms/step - loss: 2.2244 - mean_absolute_error: 1.0877 - val_loss: 3.1105 - val_mean_absolute_error: 1.4507
# Epoch 100/100
# 17/17 - 0s - 15ms/step - loss: 1.9793 - mean_absolute_error: 1.0589 - val_loss: 3.1162 - val_mean_absolute_error: 1.4493
# 3/3 - 0s - 18ms/step - loss: 2.6230 - mean_absolute_error: 1.3001
# Test Loss: 2.622969388961792, Test MAE: 1.3000596761703491

# %%
# save the model
model.save('river_height_prediction_ellagawa_model.keras')

# %%
#load the model
from tensorflow.keras.models import load_model

model = load_model('river_height_prediction_ellagawa_model.keras')

# Predictions
predictions = model.predict(test_features_reshaped)

# Plotting the predictions
plt.figure(figsize=(12, 6))
plt.plot(test_data['Date'], test_data['river_height'], label='Actual')
plt.plot(test_data['Date'], predictions, label='Predicted')
plt.title('River Height Prediction')
plt.xlabel('Date')
plt.ylabel('River Height (m)')
plt.legend()
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 451ms/step

# %%
import requests

# URL of the FastAPI endpoint
url = 'http://127.0.0.1:8000/forecast/ellagawa/'

# Data to be sent to the API
data = {
    "current_height": 2.5,
    "current_rainfall": 10.0
}

# Make the POST request and store the response
response = requests.post(url, json=data)

# Print the status code and the response data
print(f"Status Code: {response.status_code}")
print("Response Data:", response.json())
# Out:
# Status Code: 200
# Response Data: {'predictions': [9.919943809509277, 10.210724830627441, 10.216960906982422, 10.217092514038086, 10.217097282409668]}
